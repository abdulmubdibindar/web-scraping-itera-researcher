# %% [markdown]
# # Mengambil Data Researcher di Directory ITERA

# %% [markdown]
# ## Langkah 1: Instalasi Library Python
#
# Jika belum menginstal library ini, buka terminal atau command prompt dan jalankan perintah berikut:
#
# ```
# conda install -c conda-forge requests beautifulsoup4 pandas
# ```

# %% [markdown]
# ## Langkah 2: Memahami Struktur Website
#
# Sebelum menulis kode, kita perlu memahami bagaimana data diatur di website `https://directory.itera.ac.id`. Mari kita buka browser dan amati:
#
# * Halaman Utama (`https://directory.itera.ac.id`): Terlihat ada daftar program studi (Prodi). Kita perlu mengambil tautan ke setiap halaman Prodi.
# * Halaman Prodi (`https://directory.itera.ac.id/researcher/listed/88`): Di halaman ini, ada daftar nama dosen. Setiap nama dosen adalah tautan ke halaman profil dosennya. Kita perlu mengambil tautan ke setiap profil dosen.
# * Halaman Profil Dosen (`https://directory.itera.ac.id/researcher/id/gpKIfI9pZa9ql2JkaH6khJhjZWiXmGhoZLN4gJZjamVplmNjYoWigA%3D%3D`): Di halaman ini, kita akan menemukan nama dosen dan informasi kepakarannya (biasanya di bagian "Bidang Keilmuan" atau sejenisnya).

# %% [markdown]
# ## Langkah 3: Menulis Kode Python

# %% [markdown]
# ### Konfigurasi Awal

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import pandas as pd
import time # Untuk memberikan jeda agar tidak membebani server

# --- Konfigurasi Awal ---
# Pastikan base_url bersih dan hanya domain utama
base_url = "https://directory.itera.ac.id" 

# BARIS KODE BARU: Tentukan kode program studi yang ingin Anda tarik datanya di sini.
# Anda bisa menambahkan atau menghapus angka kode unik di dalam list ini.
prodi_codes_to_scrape = [
    9,   # Perencanaan Wilayah dan Kota
    10,  # Teknik Geomatika
    11,  # Teknik Sipil
    39,  # Teknologi Pangan
    88,  # Sains Data
    12   # Teknik Informatika
]

# %% [markdown]
# ### Bagian 1: Mengambil Daftar Tautan Program Studi

# %%
# --- Bagian 1: Inisialisasi Tautan Program Studi ---
print("Langkah 1: Menginisialisasi tautan untuk daftar peneliti/dosen berdasarkan kode prodi.")
prodi_links = []
for code in prodi_codes_to_scrape:
    # URL untuk daftar peneliti/dosen spesifik
    list_url = f"{base_url}/researcher/listed/{code}"
    prodi_links.append({
        "name": f"Daftar Peneliti/Dosen (Kode: {code})",
        "url": list_url,
        "code": code # Simpan kode prodi untuk pemetaan nanti
    })
    print(f"  Akan memproses: {list_url}")
print(f"  Ditemukan {len(prodi_links)} daftar peneliti/dosen untuk diproses.")

all_lecturer_profiles = []
lecturer_data = []
# Out:
# Langkah 1: Menginisialisasi tautan untuk daftar peneliti/dosen berdasarkan kode prodi.
#   Akan memproses: https://directory.itera.ac.id/researcher/listed/9
#   Akan memproses: https://directory.itera.ac.id/researcher/listed/10
#   Akan memproses: https://directory.itera.ac.id/researcher/listed/11
#   Akan memproses: https://directory.itera.ac.id/researcher/listed/39
#   Akan memproses: https://directory.itera.ac.id/researcher/listed/88
#   Akan memproses: https://directory.itera.ac.id/researcher/listed/12
#   Ditemukan 6 daftar peneliti/dosen untuk diproses.

# %% [markdown]
# ### Bagian 2: Mengambil Tautan Profil Dosen dari Setiap 'Program Studi' (Daftar Peneliti/Dosen)

# %%
# --- Bagian 2: Mengambil Tautan Profil Dosen dari Setiap Daftar Peneliti/Dosen ---
print("\nLangkah 2: Mengambil tautan profil dosen dari setiap daftar peneliti/dosen...")
for prodi in prodi_links:
    prodi_name_display = prodi['name'] # Nama prodi untuk display (misal: "Daftar Peneliti/Dosen (Kode: XX)")
    prodi_code = prodi['code'] # Kode numerik prodi
    prodi_url = prodi['url']
    print(f"  Memproses daftar: {prodi_name_display} ({prodi_url})")

    try:
        response = requests.get(prodi_url)
        response.raise_for_status() # Akan memunculkan error jika request gagal (misal: 404, 500)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Temukan semua tautan yang mengarah ke profil dosen.
        # Tautan ini harus memiliki href mengandung '/researcher/id/'
        lecturer_profile_sections = soup.find_all('a', href=lambda href: href and '/researcher/id/' in href and not '/fakultas/' in href)

        for profile_link_tag in lecturer_profile_sections:
            href_raw = profile_link_tag.get('href') # Ambil href mentah
            
            if href_raw:
                # --- PEMBENTUKAN URL YANG KRUSIAL UNTUK MENGHINDARI DUPLIKASI ---
                # Menggunakan urlparse untuk memecah href_raw
                parsed_href = urlparse(href_raw)

                # Jika href_raw sudah memiliki skema (http/https) dan network location (domain),
                # berarti itu sudah URL absolut dan tidak perlu digabungkan dengan base_url.
                if parsed_href.scheme and parsed_href.netloc:
                    full_profile_url = href_raw
                else:
                    # Jika tidak, itu adalah path relatif. Gabungkan dengan base_url.
                    # urljoin akan menangani jika href_raw dimulai dengan '/' atau tidak.
                    full_profile_url = urljoin(base_url, href_raw)
                
                # --- Tambahan Defensive: Sanitasi Akhir untuk URL yang sangat aneh ---
                # Terkadang ada sisa duplikasi, ini mencoba membersihkannya jika masih ada
                if 'directory.itera.ac.idhttps://directory.itera.ac.id' in full_profile_url:
                    full_profile_url = full_profile_url.replace('https://directory.itera.ac.idhttps://directory.itera.ac.id', 'https://directory.itera.ac.id')
                elif 'directory.itera.ac.idhttps' in full_profile_url: # Mengatasi host yang malformasi
                    # Coba perbaiki jika 'https' menempel di domain
                    full_profile_url = full_profile_url.replace('directory.itera.ac.idhttps', 'directory.itera.ac.id')
                    if not full_profile_url.startswith('https://'): # Pastikan skema tetap ada
                        full_profile_url = 'https://' + full_profile_url.lstrip('/')

                # Memastikan tidak ada duplikasi profil dosen yang sama
                # Simpan juga kode prodi asli bersama URL
                if full_profile_url not in [p['url'] for p in all_lecturer_profiles]:
                    all_lecturer_profiles.append({"prodi_code": prodi_code, "url": full_profile_url})

        time.sleep(1) # Jeda 1 detik antar permintaan halaman daftar dosen
    except requests.exceptions.RequestException as e:
        print(f"  ERROR: Gagal mengambil halaman daftar dosen {prodi_url}. Detail: {e}")
    except Exception as e:
        print(f"  ERROR: Terjadi kesalahan umum saat memproses daftar dosen {prodi_url}. Detail: {e}")

print(f"  Total ditemukan {len(all_lecturer_profiles)} tautan profil dosen unik.")
# Out:
# Langkah 2: Mengambil tautan profil dosen dari setiap daftar peneliti/dosen...
#   Memproses daftar: Daftar Peneliti/Dosen (Kode: 9) (https://directory.itera.ac.id/researcher/listed/9)
#   Memproses daftar: Daftar Peneliti/Dosen (Kode: 10) (https://directory.itera.ac.id/researcher/listed/10)
#   Memproses daftar: Daftar Peneliti/Dosen (Kode: 11) (https://directory.itera.ac.id/researcher/listed/11)
#   Memproses daftar: Daftar Peneliti/Dosen (Kode: 39) (https://directory.itera.ac.id/researcher/listed/39)
#   Memproses daftar: Daftar Peneliti/Dosen (Kode: 88) (https://directory.itera.ac.id/researcher/listed/88)
#   Memproses daftar: Daftar Peneliti/Dosen (Kode: 12) (https://directory.itera.ac.id/researcher/listed/12)
#   Total ditemukan 166 tautan profil dosen unik.

# %% [markdown]
# ### Bagian 3: Mengambil Nama Dosen dan Kepakaran dari Setiap Profil Dosen

# %%
print("\nLangkah 3: Mengambil data nama dosen dan kepakaran dari setiap profil dosen...")
for i, profile in enumerate(all_lecturer_profiles):
    profile_url = profile['url']
    prodi_code = profile['prodi_code'] # Ambil kode prodi dari data yang disimpan

    # --- FEEDBACK PROSES: Menampilkan URL yang sedang diproses ---
    print(f"  [{i+1}/{len(all_lecturer_profiles)}] Memproses profil: {profile_url}")
    # --- AKHIR FEEDBACK ---

    try:
        response = requests.get(profile_url)
        response.raise_for_status() # Akan memunculkan error jika request gagal
        soup = BeautifulSoup(response.text, 'html.parser')

        # Ekstrak Nama Dosen
        # Nama dosen berada di tag h3 di dalam <div class="card-body">
        name_tag = None
        card_body_div = soup.find('div', class_='card-body')
        if card_body_div:
            name_tag = card_body_div.find('h3') # Cari h3 di dalam div ini
        
        if not name_tag: # Fallback jika tidak ditemukan dengan metode di atas
            # Jika tidak ditemukan di dalam card-body, coba cari h3 secara umum
            name_tag = soup.find('h3') 

        lecturer_name = name_tag.get_text(strip=True) if name_tag else "<tidak ada nama>"

        # Ekstrak Kepakaran (Bidang Keilmuan)
        # Teks kepakaran berada pada elemen <p> di dalam <h2 class="section-title">Specialities</h2>
        # sekarang diganti menjadi 'Speciality Keywords'
        expertise_area = "<daftar kepakaran belum ditambahkan>"
        # Specialities diganti menjadi 'Speciality Keywords'
        # specialities_heading = soup.find('h2', class_='section-title', string=lambda text: text and 'Specialities' in text)
        specialities_heading = soup.find('h2', class_='section-title', string=lambda text: text and 'Speciality Keywords' in text)
        if specialities_heading:
            expertise_p_tag = specialities_heading.find_next_sibling('p')
            if expertise_p_tag:
                expertise_area = expertise_p_tag.get_text(strip=True)

        lecturer_data.append({
            "Nama Dosen": lecturer_name,
            "Prodi_Code": prodi_code, # Simpan kode prodi di sini
            "Kepakaran": expertise_area,
            "URL Profil": profile_url
        })
        # --- FEEDBACK PROSES: Menampilkan keberhasilan ekstraksi ---
        print(f"    BERHASIL! Data untuk '{lecturer_name}' ditemukan. Kepakaran: '{expertise_area[:70]}...'")
        # --- AKHIR FEEDBACK ---
        time.sleep(1) # Jeda 1 detik antar permintaan profil dosen
    except requests.exceptions.RequestException as e:
        print(f"  ERROR: Gagal mengambil profil {profile_url}. Status HTTP: {e.response.status_code if e.response else 'N/A'}. Detail: {e}")
    except Exception as e:
        print(f"  ERROR: Terjadi kesalahan saat memproses profil {profile_url}. Detail: {e}")

print("\nSelesai mengumpulkan data.")
# Out:
# Langkah 3: Mengambil data nama dosen dan kepakaran dari setiap profil dosen...
#   [1/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfI9paa9nlmFllYFyhY9plphlbmhkaoV3fpBpmJVna5dkk4OisA%3D%3D
#     BERHASIL! Data untuk 'M. Bobby Rahman, S.T., M.Si.(Han), Ph.D.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [2/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBiZK9ommFkk4GkhZiSk2NrmWVpZbJ3fZeWY2mabWaUa4Z5hA%3D%3D
#     BERHASIL! Data untuk 'Asirin, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [3/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBla69oa2Rlk4RxfphmY2tnl2RmaX14hZKWZGVkaGNoYn2jfg%3D%3D
#     BERHASIL! Data untuk 'Helmia Adita Fitra, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [4/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBmYq%2BWmZNkaISlf8Ril2SWbZSWYrB1rcCXlJeabZSXZrOjfQ%3D%3D
#     BERHASIL! Data untuk 'Dr. nat. techn. Shahnaz Nabila Fuady, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [5/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBmaa9nm2Vql4Z3r8VoZWVoZpKTaH91fphhZZWWmWeSZX6kgQ%3D%3D
#     BERHASIL! Data untuk 'Dr. Husna Tiara Putri, S.T., M.T.' ditemukan. Kepakaran: '...'
#   [6/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBma69kaWqVlLJzf5aTZmRkapNqZ4V3fZBoaGmWamVhln56fg%3D%3D
#     BERHASIL! Data untuk 'Dwi Bayu Prasetya, S.Si., M. Eng.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [7/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBnYq9qZWGTYn5xgpFll2mVaZKWl7B2ssJhk5doZWWUmK90gA%3D%3D
#     BERHASIL! Data untuk 'Zulqadri Ansar, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [8/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJFhYq9mZ2RhloF5rZaSl2OZbpNlZoOkgpFllWpmmWmWZ69zfQ%3D%3D
#     BERHASIL! Data untuk 'Muhamad Kumaidi, S.Pd.I., M.H.I.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [9/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJFkaK%2BXZpdil390g8SVlGdmaGlhmIBzfsFplZeZbGhjk7CnsA%3D%3D
#     BERHASIL! Data untuk 'Yudha Rahman, S.T., M.T' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [10/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJFnYq%2BVm2hqYn96g5OVa5lkmWhiaYN4ssRqlZlqbmKWmLJxgA%3D%3D
#     BERHASIL! Data untuk 'Adnin Musadri Asbi, S.Hut., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [11/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJJjY69omJOVa7JyscWTlJmXmGmSaIJ5fJiUZGZrmGpka4akfA%3D%3D
#     BERHASIL! Data untuk 'Fran Sinatra, S.P., M.T' ditemukan. Kepakaran: '...'
#   [12/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJJmZq%2BaZmSXlYN4gsCXZGqZbmhkZIB1gZZnlJdll2VmlH2kgA%3D%3D
#     BERHASIL! Data untuk 'Dr. Muhammad Zainal Ibad, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [13/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJJoY6%2BVbGaSaIalgMJiZpRlZWqUY39xr8JjlpRqmWSTaa9yhA%3D%3D
#     BERHASIL! Data untuk 'Tetty Harahap, S.T., M.Eng.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [14/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNiZq9mbWJmarBygZNoaGqZZpRoloJxrcSSaWpobGFkaoKlhA%3D%3D
#     BERHASIL! Data untuk 'Dr. Goldie Melinda Wijayanti, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [15/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNpaK%2BWl5dqZ7J4g5OXYmOYmmhlY6%2BnrsBmaGVrZWpoYoJ3fQ%3D%3D
#     BERHASIL! Data untuk 'Mia Ermawati, S.T., M.T' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [16/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRpZa9nmpJjaIN2fsGWl5loapOXZbCnspdiY5WYbJdhlYJzhQ%3D%3D
#     BERHASIL! Data untuk 'Adinda Sekar Tanjung, S.T., M.T' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [17/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRpZq9naGFkl656gsWTl5Rql2Fmaq6khZVjY2WXaZOUaIN3fA%3D%3D
#     BERHASIL! Data untuk 'Nela Agustin Kurnianingsih, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [18/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRpZ69lZ5NiZn1xrcCXaZiWZmWSaICnhJVmlWSWbZZimLB6gQ%3D%3D
#     BERHASIL! Data untuk 'Hafi Munirwan, S.T., M.Sc' ditemukan. Kepakaran: 'Urban Regeneration, Urban Redevelopment, Urban Planning...'
#   [19/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRpaK%2BWbGGVlYB0r8WUlmZrZ5doZ4Bxg5dnZWlsapdjYn94hA%3D%3D
#     BERHASIL! Data untuk 'Baiq Rindang Aprildahani, S.T., M.T' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [20/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJViZq9qaGZnZrOlspBlZpRobWVml7F4gcFhY2lpbGhimH1xsA%3D%3D
#     BERHASIL! Data untuk 'Zenia F Saraswati, S.T., M.P.W.K' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [21/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZmZ69tZmJqZH6nhZFkZ5lqbGhnaIWnf8GTZZdpbJRkYrF1rw%3D%3D
#     BERHASIL! Data untuk 'Lestari P. Winata, S.P.W.K., M.P.W.K.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [22/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJhqaa%2BYbpNilYJxrpGVk2lmZWSSaLCnr5dnZ2hrmZZna7J6fQ%3D%3D
#     BERHASIL! Data untuk 'Chania Rahma MR, S.P.W.K., M. Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [23/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJhqaq%2BZbGWUk4R5gZOUlmyXaZNkZK%2Bjr8Fla2htaJRjaa90rg%3D%3D
#     BERHASIL! Data untuk 'Hediyati Anisia Br Sinamo, S.P.W.K., M.P.W.K.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [24/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJhqa69ml2ZnZoF2r8STY5dkaZNhY39xhcSTlWiYmmmSlIBxgQ%3D%3D
#     BERHASIL! Data untuk 'Verlina Agustine, S.P.W.K., M.P.W.K.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [25/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfY9hZq%2BYmWhpaX2ngZBnlGdqlmVlmH96spiSaJhqaWZhZK%2BlhQ%3D%3D
#     BERHASIL! Data untuk 'Fachri Muhammad Rasyid, S.P.W.K., M.URP.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [26/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfY9iY69maZaSlYJxsJCVZmSVl5Nlk7KjgcOUamVmm2NmZH93fw%3D%3D
#     BERHASIL! Data untuk 'Valendya Rilansari, S.P.W.K., M.P.W.K.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [27/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfY9qaq%2BVZ5OXZa6kgMKTlWaWmpRqlbB3spFjZ2lrbmWTk7F6rQ%3D%3D
#     BERHASIL! Data untuk 'Dr. Eng. Ir. IB Ilham Malik, ST., MT.' ditemukan. Kepakaran: 'Transportation Planning, Strategic Regional Planning, City and Regiona...'
#   [28/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFiaq%2BVmGNiaoRygZdmaJdom2JoZ7GigJZplpmWbZJoZ7KihA%3D%3D
#     BERHASIL! Data untuk 'Muh. Abdi Danurja Rahman Aziz, S.T., M.R.K.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [29/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFia6%2BYlmphYn6ksZBjY2NlbWOUlK9xsMRkmGlka5ZnmK92fQ%3D%3D
#     BERHASIL! Data untuk 'Ryansyah Izhar, S.T., M.P.W.K' ditemukan. Kepakaran: '...'
#   [30/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFjYq9naGFjZ4J0so9qlJeZaWZllINxfcKTY2VolpNll4GmrQ%3D%3D
#     BERHASIL! Data untuk 'Muhammad Abdul Mubdi Bindar, S.T., M.T.' ditemukan. Kepakaran: '...'
#   [31/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJiZ6%2BZZmKXa4J2rpZkaGdnbGOVYoCmssWTZWZtlmWTY7N6fg%3D%3D
#     BERHASIL! Data untuk 'Dian Prasetyaning Sukmawati, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [32/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJqZq9mmGiXmH93gZFkl5lkmWaUmLCigMNlk5VkmWaVa4anfw%3D%3D
#     BERHASIL! Data untuk 'Dr. Asnani, S. Sos., M.A.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [33/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNhaK9rm5dqlbB5fpVnZWVsl5dlabN0f5aVmJSammmSZ4ajsA%3D%3D
#     BERHASIL! Data untuk 'Jamaludin, S.T., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [34/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNnaK9naZVjYrB3gsJkmGNpZ2mWmK%2BkfZJkaJdpbJeUk4NyfQ%3D%3D
#     BERHASIL! Data untuk 'Ir. Harkunti Pertiwi Rahayu, Ph.D.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [35/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNnaa9mlmZilX50ssNhlGZtZ2eXaX90r5dlY5iXZ2STaLN2rw%3D%3D
#     BERHASIL! Data untuk 'Ibnu Syabri, B.Sc., M.Sc., Ph.D.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [36/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNoaK%2BYl2VqaLGifpBmlpaVlpZnY7GiscGSl2lkmWhlloWmfQ%3D%3D
#     BERHASIL! Data untuk 'Vivian Alvianti, S.P.W.K., M.P.W.K.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [37/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNoaa9tm5SVk7CkfI9oZ5doa2Fha7Omr5dpmGpol5JmaIJxrQ%3D%3D
#     BERHASIL! Data untuk 'Riyad Maulana, S.P.W.K., M.R.K' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [38/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfI9jZa%2BYZ2lqarOkrcNjlWxlaJNhZYWnhI%2BWZmZoa2lqaH94rQ%3D%3D
#     BERHASIL! Data untuk 'Ir. Arif Rohman, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [39/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfI9pZ69pa5SXZbOir5OXZ2NrbmOXaLF1hJNiZ2Rkm5Rnk4Nxfg%3D%3D
#     BERHASIL! Data untuk 'Agung Pandi Nugroho, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [40/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfI9paq9pa5eVZIOjf8STaJiWlpNnk66mf8GUk2VsaWdnmK90gg%3D%3D
#     BERHASIL! Data untuk 'Tika Widayanti, S.Si., M.Si' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [41/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBoZa9qlmholbJ0g8FkYmdoaGZhZX6lgcCWZWxtmpNnmIB0fA%3D%3D
#     BERHASIL! Data untuk 'Agel Vidian Krama, S.Pd., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [42/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBoZq9nZ5STmIWnrY9ilGhom5eSabJ1fcSUZ2dnm2SVabCmrw%3D%3D
#     BERHASIL! Data untuk 'Dr. Nirmawana Simarmata, S.Pd., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [43/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBoZ6%2BZbGVqZ39xssJkZZiYmWmVZ4KjhcVmZWhrZmqTmIamhQ%3D%3D
#     BERHASIL! Data untuk 'Nurul Qamilah, S.Pd., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [44/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBoaK%2BVlpNpaYZ5gY9pZ2RrmmJmY7N3hJGWlZVkaJRnZH51gA%3D%3D
#     BERHASIL! Data untuk 'Lea Kristi Agustina, S.T., M.Eng.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [45/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBqZK9pbWJnl65xgcCSaWWVmGVqlK95hMCWlWhrmpdpYoV0rw%3D%3D
#     BERHASIL! Data untuk 'Satrio Muhammad Alif, S.T., M.T' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [46/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJFnZ69saZRoaoKlr8OUZpRplmphZX13gcNoZZaZamFkZoRzfQ%3D%3D
#     BERHASIL! Data untuk 'Zulfikar Adlan Nadzir, S.T., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [47/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRlY69omZeXmLOkrsKVlZZqa2mSarF6rY9oZ5SYa2Jjk35ygg%3D%3D
#     BERHASIL! Data untuk 'Dr.Ir. Bambang Edhi Leksono S., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [48/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJViZa%2BVmpOXZq95gcBpaGNlZmZqYoBxrsJhaWOVl2FllYJxrg%3D%3D
#     BERHASIL! Data untuk 'Agung Mahadi Putra Perdana, S.Si., M.Sc' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [49/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJVnZK%2BXl5dmZX53r5KUZGpsbWNmmIR3g5RpY5iYaWhlloCisQ%3D%3D
#     BERHASIL! Data untuk 'Redho Surya Perdana, S.T., M.T' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [50/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJVnZa9pa5ZpZLJyf5dol2SYZmJpabClfpSVaWlmZmlpk4Z5hQ%3D%3D
#     BERHASIL! Data untuk 'Adam Irwansyah Fauzi, S.T., M.T' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [51/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZmaK9llmFiaIKlfsRna2RlmmaTZrKjfJSWa2ZmmZaWY396rw%3D%3D
#     BERHASIL! Data untuk 'Ratna Mustika Sari, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [52/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZoa69tmZKWlIZ2fcJnl2qWmZaWZLNygpdjY5RpaJeXl6%2Bifg%3D%3D
#     BERHASIL! Data untuk 'Rizqi Aulia, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [53/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJdpa69plmZllYJ2fJhqaWhkbWOTa35yrpKXlpWalpZkk32jgg%3D%3D
#     BERHASIL! Data untuk 'Akbar Wahyu Nugraha, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [54/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJdqYq9lapViZn1yrZJoZmpmmpeSY4SlsMWTk5dkm5VolYVzgw%3D%3D
#     BERHASIL! Data untuk 'Een Lujainatul Isnaini, S.T., M.Eng.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [55/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJdqY69rmGpmmIB3gJCTZpVlZZKTk4WkgZVpZWqZbJSUY350rg%3D%3D
#     BERHASIL! Data untuk 'Muhammad Ulin Nuha, S.T., M.Eng.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [56/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJdqZK9lmGFnlq%2BjhZSXamdnl5RnloSmf5dmY2Vta2lkZ4Z0gQ%3D%3D
#     BERHASIL! Data untuk 'Rizky Ahmad Yudanegara, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [57/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJdqZ69qmGVjaYZ6fsBnamZkmmWXYrB4f5FqlmiWbGOUZn6ksA%3D%3D
#     BERHASIL! Data untuk 'Aulia Try Atmojo, S.Kel., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [58/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJdqaK9pbWeWY353f5dmZpdsaJOUlLN2sY9lYmhnZ2pma4J0rQ%3D%3D
#     BERHASIL! Data untuk 'Ilyas, S.Si., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [59/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfY9hZ69nmmhmYn5zfZGVl5iYapZmaK52rsBolWuYbJNnlq%2Bkrg%3D%3D
#     BERHASIL! Data untuk 'Tri Kies Welly, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [60/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfY9haK9kmJWSZLJ3fcOVaWeVaGZkarOlscBoZ2OaaJJkZ3%2BngQ%3D%3D
#     BERHASIL! Data untuk 'Ongky Anggara, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [61/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJiaa9na2NiZ692hZZpmJWWmZRqZISkrpaXaWaVa5VnZn53fg%3D%3D
#     BERHASIL! Data untuk 'Meraty Ramadhini, S.S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [62/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJjaq%2BVmZNmlH6mssRhlGtsbpdhaYJ0r8KWamiZm5Zok4Z6gg%3D%3D
#     BERHASIL! Data untuk 'Muhammad Ario Eko Rahadianto, M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [63/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJja69kmmWUZn92hZJnaplmmGGTZLF4hJCTZJVramNqZYJzgQ%3D%3D
#     BERHASIL! Data untuk 'Misfallah Nurhayati, M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [64/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBjY69ta5RlZ4B4f8RilWlqlpVnZYBxfJhpZWpmbWRmloB2gw%3D%3D
#     BERHASIL! Data untuk 'Ayudia Hardiyani Kiranaratri, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [65/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBnaq9maGFllK92sZaWk2ZtbJOSaa93r5ZnYpeZmGhmYn5yrw%3D%3D
#     BERHASIL! Data untuk 'Nugraha Bintang Wirawan, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [66/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBna69pl5KTZ655gpFmYmZlapSUl4FxsZiUk2Nqa2qTa7B0fA%3D%3D
#     BERHASIL! Data untuk 'Winny Novalina, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [67/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBoYq%2BXm2FpY7Byg5ZhmGVnlmqWl4Clr8NllGxkmmNmlLF0rg%3D%3D
#     BERHASIL! Data untuk 'Bernaditha Catur Marina, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [68/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBqa69pamJpaIGng5iVZZdrmWVpZbNyfpeWaGVpbpRlZIN5sg%3D%3D
#     BERHASIL! Data untuk 'Hermon Frederik Tambunan, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [69/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJFkaa9naJNiY32lsJhnZGNql5VolYVxrpGXamWVZ5OTaLF0rQ%3D%3D
#     BERHASIL! Data untuk 'Ahmad Yudi, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [70/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJFmZK%2BaZWdmYrCmhZdlk2qWZpaXk7F1hMWSlmuVlpKVloWjrw%3D%3D
#     BERHASIL! Data untuk 'Reza Asriandi Ekaputra, S.T., M.T.' ditemukan. Kepakaran: '#transportation modeling; #disaster management; #machine learning; #re...'
#   [71/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJJpZ69slmdjZ4Wlg8VlZWVkZWNhl4SksZJqYmpom2OVlX92sQ%3D%3D
#     BERHASIL! Data untuk 'Siti Rahma, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [72/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJJpaa%2BXlmeWloR6fpKVYmmZbGFla7JxsZJjZmRkbJJkZYBxhQ%3D%3D
#     BERHASIL! Data untuk 'Ir. Muhammad Abi Berkah Nadi, S.T., M.T., IPM.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [73/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNiZ6%2BXa2JkabOjhJOSmGZmbJRplYCjsJRlmJhkaWJpk7GlgQ%3D%3D
#     BERHASIL! Data untuk 'Dr. Eng. Rahmat Kurniawan, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [74/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNiaK9obWNhYn6kfcVpmGtpa2ZmlK6mfMJpk2pnZpOWZ4B2gQ%3D%3D
#     BERHASIL! Data untuk 'Syahidus Syuhada, S.T., M.T.' ditemukan. Kepakaran: 'Soil Mechanics, Soil Improvement, Slope Stability, Foundation Engineer...'
#   [75/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRhY6%2BabWVhk4angZCWY2uXaGVjmIN1fY9oY2Vna2hiY4WngA%3D%3D
#     BERHASIL! Data untuk 'Alfinna Mahya Ummati, S.T., M.T., M.Sc.' ditemukan. Kepakaran: 'Alfinna Mahya Ummati, Teknik Sipil, Civil Engineering, Struktur, Natio...'
#   [76/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRhZK9lbWVpl6%2BmfJhiZ2lsmWhnmH6nhZZqamZtmJdpZ7B2gg%3D%3D
#     BERHASIL! Data untuk 'Erdina Tyagita Utami, S.T., M.T.' ditemukan. Kepakaran: 'Slope stability, Retaining Walls, Soil Mechanics, Soil Improvement...'
#   [77/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRhZa9qmpRoa6%2BigI%2BSk2xrmJVlk396sJFoZ5VlZWNnZrN5gw%3D%3D
#     BERHASIL! Data untuk 'Mashuri, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [78/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRhZq9nmmlmaoNysJOSmGiWm5RjZ4R0go9qaWOVZ2OXZoN1fg%3D%3D
#     BERHASIL! Data untuk 'Dr. Miskar Maini, S.T., M.Eng.' ditemukan. Kepakaran: 'Fluvial Hydraulic, Sediment Transport, Turbulence, River Engineering, ...'
#   [79/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRhaK9ta2KVarF1fJOXlZmWZ2RqYrN2f8RhZGtqmWGUlq%2BmgA%3D%3D
#     BERHASIL! Data untuk 'Siska Apriwelni, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [80/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRlaq%2BXZWZhY7N4ssSXZ2ZnbWFhYn5yfMFnZ2psa5Jhln6kfA%3D%3D
#     BERHASIL! Data untuk 'Junita Eka Susanti, S.T., M.Eng.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [81/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRqYq9pmJaSk4V2fsCUY2aWaGeWY4WmhJVqlWRnmWqSaIB2gg%3D%3D
#     BERHASIL! Data untuk 'Dian Perwitasari, S.T., M.T' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [82/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZiZq%2BaZ5NkloZ4sMOVlWiamWdqZYZ5rcSWZ5RomZWXZYZ1fQ%3D%3D
#     BERHASIL! Data untuk 'Arif Rahman Hakim Sitepu, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [83/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZiZ69lmWeWl6%2BlrZZqk2RoaWqSk4CmssGXlZSZZpRoZISigA%3D%3D
#     BERHASIL! Data untuk 'Kirtinanda P., S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [84/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZia69pmGNpY4Omf8VkZ2Rna5Vkaa%2BiscBok2eaZmqVZoZzsA%3D%3D
#     BERHASIL! Data untuk 'Andry Yuliyanto, S.T., M.T., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [85/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZmZK%2BYbGNklK52fMBmk5aXmmOUa39zf5ViZJRtl2dhln91rg%3D%3D
#     BERHASIL! Data untuk 'Tera Melya Patrice Sihombing, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [86/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZmZq%2BabGVql355g5aXZWppbZaTl7B4hZaVk2lmaJOUk4Rxgg%3D%3D
#     BERHASIL! Data untuk 'Elian Zhafira, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [87/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJdpaa9mmGpkaLFzhcOWmGVkbGJjmIaigsKVZGtnm5aUlYWmfg%3D%3D
#     BERHASIL! Data untuk 'Michael, S.T., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [88/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJhpaK9nZ2mXl4FxfcKWmGWVZ2FpZn53gsKUaWttmmRlZ7CnsA%3D%3D
#     BERHASIL! Data untuk 'Ayu Sinta Aprilia, S.T., M.Eng.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [89/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfY9oaa9tmGOXZoSlfsOUmGuam5WVmIFysMFkaZZpaWhik4Cjrw%3D%3D
#     BERHASIL! Data untuk 'Julita Hayati, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [90/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfY9qZa9rbGmWZ4R0sJhqZ2tpbpaVan5yfJNjZGprZ2hil3%2BlhQ%3D%3D
#     BERHASIL! Data untuk 'M Gilang Indra Mardika, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [91/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFlYq9oapJnlYR3hMVlaphtmZSXlYB1fJBiY2qamZeWZ7GngQ%3D%3D
#     BERHASIL! Data untuk 'Galih Rio Prayogi, S.T., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [92/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFlZa9nbZeWa7F6fcJjlpWVZ2NiYn6jgpJnZphpaGFjZ315rQ%3D%3D
#     BERHASIL! Data untuk 'Indri Rahmandhani Fitriana, S.T., M.Eng.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [93/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJlZq%2BXmGOXk395rcOSk2Vpl2OTZLKnssRpYmZmmJNhZYN6fA%3D%3D
#     BERHASIL! Data untuk 'Dr. Ir. Sri Hendarto, S.T., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [94/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJnZK%2BWaGVoZLF5fZGSlJmXaJeXaLJ4ssFnlmlmmWNkYq5yrQ%3D%3D
#     BERHASIL! Data untuk 'Anggarani Budi Ribowo, M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [95/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJpY69saGeWlLOlfo%2BTY5llm2SSaoZzrcFhaWlna2SUaYR5sA%3D%3D
#     BERHASIL! Data untuk 'Ayu Kamila Khanza, M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [96/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJpaa%2BXbWqVZYV0fY%2BSamdlmWNpZoOlsJRpYmuabZJpZa%2BkhA%3D%3D
#     BERHASIL! Data untuk 'Cahyo Agung Saputra, S.Pd., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [97/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNkZq9kZ2NoZrF4sMJmaZRtZmlplICihZhoaGdtmWZlZIV6sQ%3D%3D
#     BERHASIL! Data untuk 'Putri Ayu Dwiyana, S.Pd., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [98/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJFlZK9qaJdoYq%2BigZhllGiaamiVYoF1scWWZWdsmZRqaYSkfQ%3D%3D
#     BERHASIL! Data untuk 'Hesti Ayuningtyas Pangastuti, S.T.P., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [99/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJFlZa9ll2KWa4R6fJBolGllZmNhln12fJhiaphomZKXlrB4rw%3D%3D
#     BERHASIL! Data untuk 'Lasuardi Permana, S.T.P., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [100/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJVpZq9ll2eUaLF1gZRlZWdpaZaUa4R1sJJiaWyWZ5JoYq%2BjsA%3D%3D
#     BERHASIL! Data untuk 'Amalia Wahyuningtyas, S.Si., M.Sc' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [101/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJdmZ69ompSTlLJ3gpaSZ5iabmdnZbJ5fpeVaGyVZ5JkmLOlsg%3D%3D
#     BERHASIL! Data untuk 'Syahrizal Nasution, M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [102/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJdmaK9qa5RoYoJyg5RmaWNrZmdlZ35zhJJna5VqZ2OVlIOigw%3D%3D
#     BERHASIL! Data untuk 'Dina Fithriyani, S.TP., M.Si' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [103/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJhlaq%2BaZZJmk7F1sphkaZZolpSXYoClhMRoZmuabGmSlq51fw%3D%3D
#     BERHASIL! Data untuk 'Ilham Marvie, S.T.P., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [104/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJhla6%2BamWJjYoamssNoYpdtlmmUY7B4sZZia5WZZ2qXlq55sg%3D%3D
#     BERHASIL! Data untuk 'Zada Agna Talitha, S.T.P., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [105/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZBiY69rZ2NoY7CihJOVapmXlmVjl31xsY%2BSk5WZZWNhk3%2BmrQ%3D%3D
#     BERHASIL! Data untuk 'Muhammad Rizky Ramanda, S.TP., M.TP.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [106/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFmZ69tmpNmk7CifphqmGtnaZdlZH6nr8KTZ2htmJJmY4Z4gg%3D%3D
#     BERHASIL! Data untuk 'Masayu Nur Ulfa, S.Gz., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [107/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFmaK9paGeXlLOjr8WUZWttm2JjlbFyfJOTaJVsbGpllIZ0hQ%3D%3D
#     BERHASIL! Data untuk 'Yosi Syafitri, S.Pt., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [108/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFpaa%2BYZmdiZIalfI%2BUZ2xqaZdhY4amrZVlaGhlaZZkZa56rw%3D%3D
#     BERHASIL! Data untuk 'Lita Lianti, M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [109/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNmaK%2BamWlpln13fcCXl5dmm2JmmLN0f5KXYmVrbZSWY396rQ%3D%3D
#     BERHASIL! Data untuk 'Wafi Adizara Muzakki, S.T.P., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [110/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNnZa9qlmSUk4KmrZdpZmyVaJdjY4R1fMSWamtpm2JnZ7B0sA%3D%3D
#     BERHASIL! Data untuk 'Okti Ruenda, S.T.P., M.T.P.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [111/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRoa6%2BYZ2mVmIR3fJRjZ5SWbZViZX53fphqZmiaZ5RplrJ0sQ%3D%3D
#     BERHASIL! Data untuk 'Afrida Nurwulan, M.Si' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [112/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRpYq9kaGppk3%2BjgZZiaJhmaWNoZ36mfcWWYmZqbWZlaH6lfA%3D%3D
#     BERHASIL! Data untuk 'Hanifa Bagus, S.T.P., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [113/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfI9pZa9ql2JkaH6khJhjZWiXmGhoZLN4gJZjamVplmNjYoWigA%3D%3D
#     BERHASIL! Data untuk 'Ahmad Luky Ramdani, S.Komp., M.Kom' ditemukan. Kepakaran: 'Integrated Circuits, Image Sensor, Interactive System, Wearable Comput...'
#   [114/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNkZ69mbJZpZrGlgMNkZ2aZbpZilYByrsGXZWiabmZkaK6msQ%3D%3D
#     BERHASIL! Data untuk 'M. Syamsuddin Wisnubroto, S.Si., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [115/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNkaa9tbZZjlbGmg8RqmGSYmJZlZbGnrsRoa2pkbJNmmH13fw%3D%3D
#     BERHASIL! Data untuk 'Tirta Setiawan, S.Pd., M.Si.' ditemukan. Kepakaran: 'Bioinformatics, Data Science...'
#   [116/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNmaK%2BZmpOTl4N6spWUamiXlmVnlIB3gJeTaJRta2FhZYKlrg%3D%3D
#     BERHASIL! Data untuk 'Febri Dwi Irawati, S.Si., M.Si' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [117/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZjZq%2BXaZWXmIRxfZGTl2SaZWZiaoRzsJGTZGiVaGWWaK9yfQ%3D%3D
#     BERHASIL! Data untuk 'Vidia, S.Si., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [118/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZmaa%2BampOUlIFxscGVmGhoamNkZK%2BkfZSUlZhlmmWXZoF1rw%3D%3D
#     BERHASIL! Data untuk 'Ade Lailani, S.Si., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [119/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJhjY6%2BamJVjY4airZVkY5WXapJnaH9yfcVhamSZmGNhlX13sQ%3D%3D
#     BERHASIL! Data untuk 'Ira Safitri, S.Si., M.Si., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [120/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJhjZK9qa2hqabGlgJhlZJlkaWZhZn6nrZVkaGNkapVmmIF1fg%3D%3D
#     BERHASIL! Data untuk 'Ardika Satria, S.Si., M.Si.' ditemukan. Kepakaran: 'Big Data...'
#   [121/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFkYq9sZpdhlq54gcKTamiaZWZolq9zfZSSZWNmmGRnla6nfQ%3D%3D
#     BERHASIL! Data untuk 'Mika Alvionita S, S.Si., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [122/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFkY69laGeUZIR6gpFla2uZbZOUZn%2BngZWXmGtqmWJmZLCngQ%3D%3D
#     BERHASIL! Data untuk 'Christyan Tamaro Nadeak, S.Si., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [123/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFpZa9klpWWlIKkhJRqa5Rrm2ZlZYV6f5VkmJiaaWeWl4Z2fA%3D%3D
#     BERHASIL! Data untuk 'Luluk Muthoharoh, S.Si., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [124/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJqaa%2BXm5aXk693g5hiYpdqmGKVarF6hZFmlGWaaZOXY6%2BmsA%3D%3D
#     BERHASIL! Data untuk 'Fajri Farid, M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [125/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNhaq9qamFqZ4Nzr5WSY5RtaGVpZrB1hJSXmGqVa5WUaX5xrg%3D%3D
#     BERHASIL! Data untuk 'Linda Rassiyanti, S.Si., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [126/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNlZa9qZpVnarB2hZVqaGZsm2dlaK%2Bmf5iVZWuamJKWY66nhA%3D%3D
#     BERHASIL! Data untuk 'Rohmi Dyah Astuti, S.Si., M.Cs.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [127/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZNnY69omJdpZ4NxgMVql5aZZZdoZbFyhZdqlJdpbmFhloCnsg%3D%3D
#     BERHASIL! Data untuk 'Yuliana, M.Cs.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [128/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRhZa%2BVmZNkk4WjsMBil5VtbmVna390ro9hZJdmbpNqZn6igA%3D%3D
#     BERHASIL! Data untuk 'Dewi Indra Setiawan, M.Si' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [129/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRhZq%2BZbGpnZLN3sZVnZWpsmpOUlK94gJJklJZraGVkY693fg%3D%3D
#     BERHASIL! Data untuk 'Fitri Nurjanah, S.Si., M.Mat.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [130/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRhZ6%2BXZWKTZ7B6gZFjl2ZqaZJmaYSng5SSaWeVaJVnl350gg%3D%3D
#     BERHASIL! Data untuk 'Yusni Puspha Lestari, S.T., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [131/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRhaK%2BWZZKXa4VyrY%2BUaJRnl5djk4SjfJRjZGZpa5RlaLF4fA%3D%3D
#     BERHASIL! Data untuk 'Yustida Bellini, M.Kom' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [132/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRhaa9qmGFmZINxfsWTa5iZl2iSa4GkrpNqYmNrbJOSloB1fQ%3D%3D
#     BERHASIL! Data untuk 'Rafika Sari, S.Si., M.Si' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [133/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRhaq9rZmGUloR5r8SUaWlqamVlaIF6rZZmY2VlbmSTaH9xfQ%3D%3D
#     BERHASIL! Data untuk 'Rian Kurnia, M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [134/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRha6%2BXaWSTlH55hZBnaZaVZmlolIN6g5JjamyWmmVnZH%2Bmsg%3D%3D
#     BERHASIL! Data untuk 'Yoga Aji Sukma, S.Mat., M.Stat.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [135/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRiYq%2BYbpRiY66ksMNkZGdmbJJnZ7Onfo%2BWk5lmbJdjZoaigw%3D%3D
#     BERHASIL! Data untuk 'Indah Suciati, M.Mat.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [136/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRiY6%2BZmGWVaX6kgcSSaWeaZWeVlIV6gpdiZmeXaGSSarB1gw%3D%3D
#     BERHASIL! Data untuk 'Dimas Dwi Randa, M.KOM' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [137/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZRiZK%2BWmWlnloN1fsBoZmxsZ5WVan94gY%2BSZJeXZWdpan51gQ%3D%3D
#     BERHASIL! Data untuk 'Vina Nurmadani, S.Mat, M.Si' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [138/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBnaK%2BWbZKXlH51sZCVZGVom2dnabCihcWSamxmZmFoa7B5gg%3D%3D
#     BERHASIL! Data untuk 'Rajif Agung Yunmar, S.Kom., M.Cs.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [139/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBnaa9km5VhlIGkhY9kZWeZmpZkY7N5gcJnapmVbGVomIF3gw%3D%3D
#     BERHASIL! Data untuk 'Raidah Hanifah, S.T., M.T.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [140/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBpY69ommKXZn5zgsOXZWVtmmdhZH%2BkgJOUaZdpm5JqZoJxfg%3D%3D
#     BERHASIL! Data untuk 'Arkham Zahri Rakhman, S.Kom., M.Eng.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [141/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBpZK9qmGNhaYWnfMKUameYZWNjZ4F3hMJhmJVqbmRhZ4F4hA%3D%3D
#     BERHASIL! Data untuk 'Rahman Indra Kesuma, S.Kom. M.Cs.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [142/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJBpZa%2BVmpSTmH51f8GTZmyZZmJjY7Cngo%2BTk2OaapKSZIZ3fQ%3D%3D
#     BERHASIL! Data untuk 'Hafiz Budi Firmansyah, S.Kom., M.Sc., Ph.D.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [143/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJFlaa%2BYmZdhZYJ4fphqk5eWaGRia4N3gJGUa2iXaGOXZ7N1gA%3D%3D
#     BERHASIL! Data untuk 'Imam Eko Wicaksono, S.Si., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [144/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJFmaq%2BabZJkaoR6gY9hamdtmpaWa4OkfJeSl2htZmVnY4V5gA%3D%3D
#     BERHASIL! Data untuk 'I Wayan Wiprayoga Wisesa, S.Kom., M.Kom.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [145/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJJpY69mlmlik651rpNna2eZa2VmlrB2rZSSlWxrm2Vkln2isQ%3D%3D
#     BERHASIL! Data untuk 'Amirul Iqbal, S.Kom., M.Eng' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [146/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJJpZK%2BZlmhqZ7ClfphhYmOZbWdkla95f5hoY2ZmmpeTaoWjhQ%3D%3D
#     BERHASIL! Data untuk 'Hartanto Tantriawan, S.Kom., M.Kom' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [147/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJJpZa%2BZm2aTY66lgsBkYmhobJdjarF5gZJomGdkaZVnlYVyfw%3D%3D
#     BERHASIL! Data untuk 'Angga Wijaya, S.Si., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [148/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNjZK9nlmFmk69zscGWaJRtl5ZlZq6mfo%2BVl5lqm2RhZLF0rQ%3D%3D
#     BERHASIL! Data untuk 'Mohamad Idris, S.Si., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [149/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNjZq9rm5Zkk7Olg8VkYmVqmmRhZa5xsZeXZJSYaJJnlrN2fw%3D%3D
#     BERHASIL! Data untuk 'Arief Ichwani, S.Kom., M.Cs' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [150/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNqZq9rbJWXmIF6fMNok2lpaGKTlLJzfpJlaGVmZWhhZbKifQ%3D%3D
#     BERHASIL! Data untuk 'Martin Clinton Tosima Manullang, S.T., M.T., Ph.D.' ditemukan. Kepakaran: 'Embedded System, Computer Engineering, Internet of Things, Tele-Health...'
#   [151/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJNqZ6%2BZaZVjZ32lrZiTY2tommJoln50fcVqZ2qYZ2WWaISirQ%3D%3D
#     BERHASIL! Data untuk 'Andika Setiawan, S.Kom., M.Cs.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [152/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRnaq9sZZVjYoWjgsWXY2aVmZdll391fMFjaGtlZmplk4Z0gw%3D%3D
#     BERHASIL! Data untuk 'Meida Cahyo Untoro, S.Kom., M.Kom' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [153/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRoYq9pZ2qTYoOispFklGRklmFkmK%2BnhJGXapRplmSUZrOjrw%3D%3D
#     BERHASIL! Data untuk 'Ilham Firman Ashari, S.Kom., M.T' ditemukan. Kepakaran: '...'
#   [154/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRoY6%2BaapVll7CmgZSUYmdnmWJpmH53fcRhamWWZZVlk4Fygw%3D%3D
#     BERHASIL! Data untuk 'Ir. Mugi Praseptiawan, S.T., M.Kom.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [155/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRpY69raZZpZ4JzgphomGWZlmNnYrJ0rY9hapiVbGhnY4B3fA%3D%3D
#     BERHASIL! Data untuk 'Andre Febrianto, S.Kom., M.Eng' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [156/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJRpZK%2Bam2hoYrJ5gZOTZWNrammXk4Slr5ZiZWtrameWloN2rw%3D%3D
#     BERHASIL! Data untuk 'Aidil Afriansyah, S.Kom., M.Kom' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [157/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJZqaq%2BaZ5WWZLF4rcSUYpZpm2RjmIWnf8RiYmpkmGNplH%2Bkfw%3D%3D
#     BERHASIL! Data untuk 'Hira Laksmiwati Soemitro, M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [158/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJhkZ6%2BabGJjlYOlspZnmGppZWZpZ7CjgpRiY2eXapdpl7OmsQ%3D%3D
#     BERHASIL! Data untuk 'Eko Dwi Nugroho, S.Kom., M.Cs.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [159/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfJhkaK9ql5RjZIZ2sJBqZWZkl5dja6%2Bmf5dmZGaYaJJhk7F3hQ%3D%3D
#     BERHASIL! Data untuk 'Muhammad Habib Algifari, S.Kom., M.T.I.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [160/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfY9iaq%2BWmWWSaYN0fJaSlmdtm5OVaYF6gphla5eVmpNnZX91gg%3D%3D
#     BERHASIL! Data untuk 'Leslie Anggraini, S.Kom., M.Cs.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [161/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZBiZK9pZmFoZH%2BisMNlaJial2dmlH2khZdjlWxqlmFhln90sQ%3D%3D
#     BERHASIL! Data untuk 'Winda Yulita, M.Cs.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [162/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZBoZq9la2dplLOmssCSY2pnaWiTlrOkspNoY5hsl2Jll4OnrQ%3D%3D
#     BERHASIL! Data untuk 'Radhinka Bagaskara, S.Si.Kom., M.Si., M.Sc.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [163/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZBpZK9oZ2qSYq5xg8NjaWlom2NoaYGnssNjYpmWbGqTY4Cmgw%3D%3D
#     BERHASIL! Data untuk 'Alya Khairunnisa Rizkita, S.Kom., M.Kom.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [164/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZFqZK9kmGZha7N0fpdkY2NmZWFjZ7F5g5KUmGmWaZWWYn50rw%3D%3D
#     BERHASIL! Data untuk 'Miranti Verdiana, M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [165/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJlaq9samiWZK96rcFnaGuXaGNnZ4Clr5FjZGtmapNqZ6%2Bjsg%3D%3D
#     BERHASIL! Data untuk 'Prof. Dr. Eng. Ir. Sarwono Sutikno, CISA' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#   [166/166] Memproses profil: https://directory.itera.ac.id/researcher/id/gpKIfZJmY69naWiWlH6jsZeUlGaVlmllY36lrZaUlWplm2pkY7F6rg%3D%3D
#     BERHASIL! Data untuk 'Siswanto, S.Pd., M.Si.' ditemukan. Kepakaran: '<daftar kepakaran belum ditambahkan>...'
#
# Selesai mengumpulkan data.

# %% [markdown]
# ### Bagian 4: Memproses dan Menyimpan Data ke Format Tabel (CSV/Excel)

# %%
# --- Bagian 4: Memproses Data ke Format Tabel (Pandas DataFrame) ---
print("\nLangkah 4: Memproses data dan menampilkannya dalam format tabel...")

if lecturer_data:
    # 1. Buat DataFrame dari data yang dikumpulkan
    df = pd.DataFrame(lecturer_data)

    # 2. Definisikan pemetaan kode prodi ke nama lengkap
    prodi_name_mapping = {
        9: "Perencanaan Wilayah dan Kota",
        10: "Teknik Geomatika",
        11: "Teknik Sipil",
        39: "Teknologi Pangan",
        88: "Sains Data",
        12: "Teknik Informatika",
        36: "Daftar Umum Peneliti/Dosen" # Tambahkan ini jika kode 36 juga digunakan
    }

    # 3. Ubah kolom 'Prodi_Code' menjadi 'Program Studi' dengan nama lengkap
    df['Program Studi'] = df['Prodi_Code'].map(prodi_name_mapping)

    # 4. Hapus kolom 'Prodi_Code' karena sudah diganti dengan 'Program Studi'
    df = df.drop(columns=['Prodi_Code'])

    # 5. Atur ulang urutan kolom agar 'Program Studi' berada di posisi yang logis
    desired_columns_order = ["Nama Dosen", "Program Studi", "Kepakaran", "URL Profil"]
    df = df[desired_columns_order]

    print("\nBerikut adalah 5 baris pertama dari tabel data yang dihasilkan:")
    print(df.head().to_string()) # Menampilkan 5 baris pertama DataFrame ke konsol
    print(f"\nTotal data dosen yang berhasil dikumpulkan: {len(df)} baris.")

    # --- Bagian 5: Mengekspor Data ke CSV ---
    print("\nLangkah 5: Mengekspor data ke file CSV...")
    output_csv_filename = "data_kepakaran_dosen_itera_2050720.csv"
    try:
        df.to_csv(output_csv_filename, index=False, encoding='utf-8', sep = ';')
        print(f"Data berhasil disimpan ke {output_csv_filename} dengan delimiter ';'.")
    except Exception as e:
        print(f"ERROR: Gagal menyimpan data ke CSV. Detail: {e}")

else:
    print("Tidak ada data dosen yang berhasil dikumpulkan untuk diproses menjadi tabel atau diekspor.")
# Out:
# Langkah 4: Memproses data dan menampilkannya dalam format tabel...
#
# Berikut adalah 5 baris pertama dari tabel data yang dihasilkan:
#                                          Nama Dosen                 Program Studi                  Kepakaran                                                                                                  URL Profil
# 0          M. Bobby Rahman, S.T., M.Si.(Han), Ph.D.  Perencanaan Wilayah dan Kota  Kepakaran Tidak Ditemukan    https://directory.itera.ac.id/researcher/id/gpKIfI9paa9nlmFllYFyhY9plphlbmhkaoV3fpBpmJVna5dkk4OisA%3D%3D
# 1                                Asirin, S.T., M.T.  Perencanaan Wilayah dan Kota  Kepakaran Tidak Ditemukan    https://directory.itera.ac.id/researcher/id/gpKIfJBiZK9ommFkk4GkhZiSk2NrmWVpZbJ3fZeWY2mabWaUa4Z5hA%3D%3D
# 2                    Helmia Adita Fitra, S.T., M.T.  Perencanaan Wilayah dan Kota  Kepakaran Tidak Ditemukan    https://directory.itera.ac.id/researcher/id/gpKIfJBla69oa2Rlk4RxfphmY2tnl2RmaX14hZKWZGVkaGNoYn2jfg%3D%3D
# 3  Dr. nat. techn. Shahnaz Nabila Fuady, S.T., M.T.  Perencanaan Wilayah dan Kota  Kepakaran Tidak Ditemukan  https://directory.itera.ac.id/researcher/id/gpKIfJBmYq%2BWmZNkaISlf8Ril2SWbZSWYrB1rcCXlJeabZSXZrOjfQ%3D%3D
# 4                 Dr. Husna Tiara Putri, S.T., M.T.  Perencanaan Wilayah dan Kota                               https://directory.itera.ac.id/researcher/id/gpKIfJBmaa9nm2Vql4Z3r8VoZWVoZpKTaH91fphhZZWWmWeSZX6kgQ%3D%3D
#
# Total data dosen yang berhasil dikumpulkan: 246 baris.
#
# Langkah 5: Mengekspor data ke file CSV...
# Data berhasil disimpan ke data_kepakaran_dosen_itera_2050720.csv dengan delimiter ';'.
